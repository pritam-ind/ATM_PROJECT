# %%
import time

# print("Welcome to MY BANK OF INDIA\nATM Service Available 24x7\nInsert Your Card To Proceed!\n")
# time.sleep(3)

balance = 5000
pin = "1111"
# history = []    #to add yet

attempts = 3
while attempts > 0:
    print("Welcome to MY BANK OF INDIA\nATM Service Available 24x7\nInsert Your Card To Proceed!\n")
    time.sleep(3)
    
    pin = input("Enter the ATM PIN here: ").strip()
    print("\nVerifying your PIN, Please wait..................\n")
    time.sleep(2)
    
    if pin == "1111":
        print("PIN Verified.")
        withdraw = int(input("Enter the amount you want to withdraw: "))
        
        if withdraw <= balance:
            print("Processing your payment...................")
            time.sleep(2)
            print("\nTransaction Successfule.\nPlease collect your payment!")
            balance -= withdraw
            print(f"Left balance in account :{balance}")
            break
        else: 
            print("\n.........................................\nInsuffiecient Balance to Withdraw\nPlease Enter a Valid Amount to Withdraw!")
            print(f"[Balance in your account is: {balance}]\n\n❌Transaction Failed! .........................................\n")
            if attempts >= 1:
                print("Remove your card and try again\n")  # yaha tic tic .. ... ... add karna hai abhi
            time.sleep(5)
            

    else:
        attempts -= 1
        print(f"🚫Transaction Denied\nPlease Enter a Correct PIN!\nWarning: {attempts} attempts left with you.\n")
        if attempts >= 1:
            print("Remove your card and try again")
            print(".........................................\n.........................................\n")
            
        time.sleep(5)
        

if attempts == 0:
    print("\nYour card has been blocked!\nPlease Contact Your Branch!\n")
