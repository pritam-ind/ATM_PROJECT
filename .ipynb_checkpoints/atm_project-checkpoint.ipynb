# %%
import time

balance = 5000
pin = "1111"
history = [] 

attempts = 3
while attempts > 0:
    pin = int(input("Enter the ATM PIN here: ")).split()
    print("Verifying your PIN, Please wait..................")
    time.sleep(2)
    
    if pin == "1111":
        withdraw = int(input("Enter the amount you want to withdraw: "))
        
        if withdraw <= balance:
            print("Processing your payment...................")
            time.sleep(2)
            print("\nPlease collect your payment!")
            balance -= withdraw
            break
        else: 
            print("\nInsuffiecient Balance to Withdraw\nPlease Enter a Amount to Withdraw!")
            print(f"\nBalance in your is: {balance}")

    else:
        attempts -= 1
        print(f"Please Enter a Correct PIN!\nWarning: {attempts} left with you.\n"})

print("\nYour card has been blocked!\nPlease Contact Your Branch!\n")
    
        
    
    
# def show_balance():
#     print(f"\n[INFO] Your current balance is: ₹{balance}")

# def withdraw():
#     global balance
#     try:
#         amount = int(input("Enter amount to withdraw: "))
        
#         if amount <= 0:
#             print("Invalid amount. Please enter a positive value.")
#             return

#         if amount <= balance:
#             print("Processing transaction...")
#             time.sleep(2) # 2 seconds delay
#             balance -= amount
#             history.append(f"Withdrawn: ₹{amount}") # Adding to history
#             print(f"Success! Please collect your cash: ₹{amount}")
#             print(f"Remaining Balance: ₹{balance}")
#         else:
#             print("Transaction Failed: Insufficient Funds!")
            
#     except ValueError:
#         print("Error: Please enter a valid number.")

# def deposit():
#     global balance
#     try:
#         amount = int(input("Enter amount to deposit: "))
        
#         if amount > 0:
#             print("Depositing cash...")
#             time.sleep(1.5)
#             balance += amount
#             history.append(f"Deposited: ₹{amount}") # Adding to history
#             print(f"Success! New Balance: ₹{balance}")
#         else:
#             print("Invalid amount.")
            
#     except ValueError:
#         print("Error: Please enter a valid number.")

# def mini_statement():
#     print("\n LAST TRANSACTIONS 
#     ")
#     if not history:
#         print("No transactions yet.")
#     else:
#         for transaction in history:
#             print(f"> {transaction}")
#     print("-------------------------")

# # main program
# print("Welcome to Python Bank ATM")
# attempts = 0

# while attempts < 3:
#     user_pin = input("\nPlease enter your 4-digit PIN: ")

#     if user_pin == pin:
#         print("Access Granted!")
#         time.sleep(1)
        
#         while True:
#             print("\n" + "="*25)
#             print("Press 1 to Withdraw Cash")
#             print("Press 2 to Deposit Cash")
#             print("Press 3 to Check Balance")
#             print("Press 4 to Mini Statement")
#             print("Press 5 to Exit")
#             print("="*25)
            
#             choice = input("Select an option (1-5): ")

#             if choice == "1":
#                 withdraw()
#             elif choice == "2":
#                 deposit()
#             elif choice == "3":
#                 show_balance()
#             elif choice == "4":
#                 mini_statement()
#             elif choice == "5":
#                 print("Thank you for using Python Bank. Have a nice day!")
#                 break
#             else:
#                 print("Invalid choice. Please try again.")
#         break # Break the outer loop after finishing transaction
#     else:
#         attempts += 1
#         print(f"Wrong PIN! Attempts remaining: {3 - attempts}")

# if attempts == 3:
#     print("\n[LOCKED] Too many wrong attempts. Your card is blocked.")
# Out:
#   Cell In[1], line 10
#     print("Verifying your PIN, Please wait.................."))
#                                                               ^
# SyntaxError: unmatched ')'
